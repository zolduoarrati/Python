# %% [markdown]
# <a href="https://colab.research.google.com/github/zolduoarrati/Python/blob/master/PARROT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-h28v3h9s
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-h28v3h9s
# ...
#      |████████████████████████████████| 2.9 MB 10.0 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 47.5 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 78 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 59.1 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 636 kB 44.6 MB/s
# ...
#   Created wheel for parrot: filename=parrot-1.0-py3-none-any.whl size=8695 sha256=5b1b7cb17ea4d94588b88f326220008bf7923d26e58afe6d696146fb5e702bcb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1taj5zie/wheels/d8/27/d8/b757755a5b0b804c59714fdd8a4e2733c20802f638f17f7d96
# ...

# %%
# Import libraries
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
# For reproducibility
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
#Init models (make sure you init ONLY once if you integrate this to your code)
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/736 [00:00<?, ?B/s]
# ...

# %%
phrases = ["terms such as diversity and heterogeneity have been borrowed from older fields such as ecology by computer science to describe systems for many years"]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  terms such as diversity and heterogeneity have been borrowed from older fields such as ecology by computer science to describe systems for many years
# ----------------------------------------------------------------------------------------------------
# ('for many years computers have borrowed terms such as diversity and heterogeneity from earlier fields such as ecology for the purpose of descriptions of systems such as', 92)
# ('concepts such as diversity and heterogeneity have been borrowed for many years by computer science from older fields such as ecology to describe systems', 80)
# ('for many years the terms diversity and heterogeneity have been borrowed by computer science from older fields such as ecology to describe systems', 75)
# ...
